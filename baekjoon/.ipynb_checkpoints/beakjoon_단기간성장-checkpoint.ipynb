# %% [markdown]
# ## 평범한 배낭

# %%
n,k=map(int,input().split())
A={}
for i in range(n):
    w,v=map(int,input().split())
    A[w]=v
    W=[]
    V=[]
    for value in A.values():
        V.append(value)
    for key in A.keys():
        W.append(key)


B={}
o=0
j=n
n=1
O=0
J=0
while True:
    if j < len(W)-1:
        O=O+W[o]+W[j]
        J=A[W[o]]+A[W[j]]
        B[O]=J
        O=O-W[o]
        j+=1
    elif j == len(W)-1:
        o+=1
        O=0
        J=0
        j=n+1
    if o == len(W)-1:
        break
# Out:
# 4 7
# 6 13
# 4 8
# 3 6
# 5 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 21>()
#      25     O=O-W[o]
#      26     j+=1
# ---> 27 elif j == len(W)-1:
#      28     o+=1
#      29     O=0
#
# KeyboardInterrupt:

# %%
n, k = map(int, input().split())
A = {}
for i in range(n):
    w, v = map(int, input().split())
    A[w] = v
    W = []
    V = []
    for value in A.values():
        V.append(value)
    for key in  A.keys():
        W.append(key)
B = []
o = 0
p = 0
q = 0
t = 0
j = len(V)
while True:
    if W[o] > k and o < len(W)-1:
        o += 1
    elif W[o] == k and o < len(W)-1:
        t  = t+A[W[o]]
        B.append(t)
        t =0
        o += 1
    elif W[o] < k and o < len(W)-1:
        t = t+A[W[o]]
        B.append(t)
        t =0
        p = p+W[o]
        if p > k:
            p = p-W[o]
            o += 1
        elif p < k:
            q = q+A[W[o]]
            B.append(q)
            o += 1
        elif p == k:
            q = q+A[W[o]]
            B.append(q)
            p = p-W[o]
            q = q-A[W[o]]
            o += 1

    elif W[o] < k and o < len(W)-1:
        t = t+A[W[o]]
        B.append(t)
        t =0
        p = p+W[o]
        o +=1
        if p > k:
            p = p-W[o]
            o += 1
        elif p < k:
            q = q+A[W[o]]
            B.append(q)
            o += 1
        elif p == k:
            q = q+A[W[o]]
            B.append(q)
            p = p-W[o]
            q = q-A[W[o]]
            o += 1


    elif o == len(W)-1:
        if W[o] <= k:
            t = t+A[W[o]]
            B.append(t)
            t = 0
            p = p+W[o]
            if p > k:
                p = 0
                q = 0
                o = o+2-j
                j = j-1
            elif p <= k:
                q = q+A[W[o]]
                B.append(q)
                p = 0
                q = 0
                o = o+2-j
                j = j-1
        elif W[o] > k:
            p = 0
            q = 0
            o = o+2-j
            j = j-1
            continue
    if j <= 1:
        break
        
B = []
o = 0
p = 0
q = 0
t = 
j = len(V)
while True:
    if W[o] > k and o < len(W)-1:
        o += 1
    elif W[o] == k and o < len(W)-1:
        t  = t+A[W[o]]
        B.append(t)
        t =0
        o += 1
    elif W[o] < k and o < len(W)-1:
        t = t+A[W[o]]
        B.append(t)
        t =0
        p = p+W[o]
        if p > k:
            p = p-W[o]
            o += 1
        elif p < k:
            q = q+A[W[o]]
            B.append(q)
            o += 1
        elif p == k:
            q = q+A[W[o]]
            B.append(q)
            p = p-W[o]
            q = q-A[W[o]]
            o += 1

    elif W[o] < k and o < len(W)-1:
        t = t+A[W[o]]
        B.append(t)
        t =0
        p = p+W[o]
        o +=1
        if p > k:
            p = p-W[o]
            o += 1
        elif p < k:
            q = q+A[W[o]]
            B.append(q)
            o += 1
        elif p == k:
            q = q+A[W[o]]
            B.append(q)
            p = p-W[o]
            q = q-A[W[o]]
            o += 1


    elif o == len(W)-1:
        if W[o] <= k:
            t = t+A[W[o]]
            B.append(t)
            t = 0
            p = p+W[o]
            if p > k:
                p = 0
                q = 0
                o = o+2-j
                j = j-1
            elif p <= k:
                q = q+A[W[o]]
                B.append(q)
                p = 0
                q = 0
                o = o+2-j
                j = j-1
        elif W[o] > k:
            p = 0
            q = 0
            o = o+2-j
            j = j-1
            continue
    if j <= 1:
        break
# Out:
# 4 7
# 6 13
# 4 8
# 3 6
# 5 12
# [6, 4, 3, 5]
# [13, 8, 6, 12]

# %%
# Out:
# 2
